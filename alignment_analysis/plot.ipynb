# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
reads_nagoyadf = pd.read_csv("mapped-nagoya.tsv", sep='\t')
reads_nicaraguadf = pd.read_csv("mapped-nicaragua.tsv", sep='\t')
reads_phdf = pd.read_csv("mapped-philippines.tsv", sep='\t')

readsdf = pd.concat([reads_nagoyadf, reads_nicaraguadf, reads_phdf])
readsdf.head()

# %%
headers = ["incorrect", "correct", "sample_id", "aligner", "country"]
# brazildf = pd.read_csv("plot_alns-brazil.tsv", sep='\t', names=headers, header=None)
correct_nagoyadf = pd.read_csv("plot_alns-nagoya.tsv", sep='\t', names=headers, header=None)
correct_nicaraguadf = pd.read_csv("plot_alns-nicaragua.tsv", sep='\t', names=headers, header=None)
correct_phdf = pd.read_csv("plot_alns-ph.tsv", sep='\t', names=headers, header=None)

# %%
correctdf = pd.concat([correct_nagoyadf, correct_nicaraguadf, correct_phdf])
correctdf.head()
# Out:
#    incorrect   correct   sample_id       aligner country
# 0   0.104523  0.895477  SRR7993842          last  Brazil
# 1   0.106396  0.893604  SRR7993842  last trained  Brazil
# 2   0.150884  0.849116  SRR7993842       bowtie2  Brazil
# 3   0.047867  0.952133  SRR7993843          last  Brazil
# 4   0.049824  0.950176  SRR7993843  last trained  Brazil

# %%
correctdf.merge(readsdf, left_on='Sample ID', right_on='sample_id')

# %%
g = sns.FacetGrid(merged, col='country')

g.map(sns.barplot, 'sample_id', 'correct', 'aligner')
g.set_axis_labels('Samples', 'Correctly Aligned')
g.add_legend()
plt.tight_layout()

plt.show()
# Out:
# /Users/kimwilliamelee/miniforge3/lib/python3.10/site-packages/seaborn/axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/kimwilliamelee/miniforge3/lib/python3.10/site-packages/seaborn/axisgrid.py:717: UserWarning: Using the barplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# Out:
# /Users/kimwilliamelee/miniforge3/lib/python3.10/site-packages/seaborn/axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/kimwilliamelee/miniforge3/lib/python3.10/site-packages/seaborn/axisgrid.py:717: UserWarning: Using the barplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
